# %%
strA="A"
strB="B"
concatenate=strA+strB
print(concatenate)
# Out:
# AB

# %%
sum=0
for i in range(10):
    sum=sum+i
print(sum)
# Out:
# 45

# %%
# Print 0+1+...+9

l = [1, 2, 3]
print(l, type(l))

l = [1, 2, 3, "string"]
print(l, type(l))
# Out:
# [1, 2, 3] <class 'list'>
# [1, 2, 3, 'string'] <class 'list'>

# %%
l = [1, 2, 3, [1, 2, 3], "string"]
print(l[3][1])
# Out:
# 2

# %%
a, b, c = (3, 4, 5)
print(a, b, c)
# Out:
# 3 4 5

# %%
def sum (a,b):
    s=a+b
    return s
sum (2,5)
# Out:
# 7

# %%
def calculate (a,b) :
    sum = a + b
    sub = a - b
    mul = a * b
    d = a / b
    return (sum, sub, mul, d) 
calculate(1,2)
# Out:
# (3, -1, 2, 0.5)

# %%
calculate(1,2)
# Out:
# (3, -1, 2, 0.5)

# %%
sum, sub, mul , d = calculate(1, 2)
print (sum, sub , mul, d)
# Out:
# 3 -1 2 0.5
